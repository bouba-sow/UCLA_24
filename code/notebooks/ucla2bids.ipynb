# %%
from pathlib import Path
UCLA_data = Path("/store/scratch/bsow/Documents/UCLA_24/data/ucla_data")
BIDS_root = Path("/store/scratch/bsow/Documents/UCLA_24/data/BIDS")
BIDS_root.mkdir(parents=True, exist_ok=True)

# list of patients (first level folders inside UCLA_data)
patients = list(UCLA_data.glob("*"))
patients_ids = [str(patient_path).split("/")[-1] for patient_path in patients]

print(patients_ids)
# Out:
# ['572']
